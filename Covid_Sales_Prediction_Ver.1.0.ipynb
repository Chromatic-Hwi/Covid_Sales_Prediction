# %% [markdown]
# # Covid Sales Prediction

# %% [markdown]
# ### 목차

# %%
"""
1. 모듈 임포트

2. 데이터 처리

3. 그래프 확인

4. 데이터 정규화 

5. 데이터 연관성 분석

6. 이상치 처리
    -이상치 확인 함수 생성
    -분위별 이상치 1차 검색
    -이상치 치환
    -처리 후 잔여 개수 확인

7. 데이터셋 편집

8. 딥러닝 모델

9. 결과 표시
    -그래프 표시
    -그래프 비교 결과
    -성능 측정 지표

10. 예측값과 실제값 결과 csv 파일 저장
"""
# Out:
# '\n1. 모듈 임포트\n\n2. 데이터 처리\n\n3. 그래프 확인\n\n4. 데이터 정규화 \n\n5. 데이터 연관성 분석\n\n6. 이상치 처리\n    -이상치 확인 함수 생성\n    -분위별 이상치 1차 검색\n    -이상치 치환\n    -처리 후 잔여 개수 확인\n\n7. 데이터셋 편집\n\n8. 딥러닝 모델\n\n9. 결과 표시\n    -그래프 표시\n    -그래프 비교 결과\n    -성능 측정 지표\n\n10. 예측값과 실제값 결과 csv 파일 저장\n'

# %% [markdown]
# ### <화면 가로 확장>

# %%
# 화면 가로 확장 코드 (기본 width 50%)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### 1. 모듈 임포트

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import tensorflow as tf
import csv
import os
import datetime

# %% [markdown]
# ### <GPU 확인>

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### 2. 데이터

# %% [markdown]
# #### 배달의 민족 월별 정산 데이터 저장

# %%
try:
    os.mkdir('./Data')
    os.mkdir('./Data/BaeMin')
    print('폴더 생성 완료.')
    
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.')
# Out:
# 폴더 생성 완료.

# %%
for BM in range(1, len(os.listdir('./Original_Data/BaeMin'))+1):
    if BM<7:
        count_num='0'+str(BM)
        data_bm = pd.read_excel('./Original_Data/BaeMin/배달의민족-2021년'+count_num+'월_정산명세서_성정환사장님.xlsx', sheet_name='상세')
        data_bm = data_bm.iloc[3:, [0, 20]] # 행, 열 제한으로 필요 정보 추출
    if (BM>=7 and BM<10):
        count_num='0'+str(BM)
        data_bm = pd.read_excel('./Original_Data/BaeMin/배달의민족-2021년'+count_num+'월_정산명세서_성정환사장님.xlsx', sheet_name='상세')
        data_bm = data_bm.iloc[3:, [0, 21]] # 행, 열 제한으로 필요 정보 추출
    if BM>=10:
        count_num=str(BM)
        data_bm = pd.read_excel('./Original_Data/BaeMin/배달의민족-2021년'+count_num+'월_정산명세서_성정환사장님.xlsx', sheet_name='상세')
        data_bm = data_bm.iloc[3:, [0, 21]] 
    
    data_bm = data_bm.reset_index(drop=True) # 인덱스 초기화
    data_bm.to_csv('./Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv', header=False, encoding='cp949')
    data_bm_named=pd.read_csv('./Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv', names=['Date','Won'], encoding='cp949')
    data_bm_named.to_csv('./Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv', encoding='cp949')

# %%
# 1년 단위 파일로 병합
bm_y = pd.DataFrame()
for y in range(1, len(os.listdir('./Data/BaeMin'))+1):
    if y<=9:
        count_num='0'+str(y)
    else:
        count_num=str(y)
        
    file = './Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv'
    bm_m= pd.read_csv(file, encoding='cp949')
    bm_y = pd.concat([bm_y, bm_m])
    
bm_y = bm_y.drop([bm_y.columns[0]], axis=1)
bm_y = bm_y.reset_index(drop=True)
bm_y.to_csv('./Data/배달의 민족_2021년_수익정산.csv', encoding='cp949')

# 중간에 0이 있는데 코로나 때문에 0이 된게 아니라면 이상치 처리를 해야함.

# %%
data_bm_sum=pd.DataFrame(columns=['Date','Won'])
data_bm=pd.read_csv('./Data/배달의 민족_2021년_수익정산.csv', encoding='cp949')
data_bm = data_bm.drop([data_bm.columns[0]], axis=1)

for D in range(len(data_bm)-1):
    y=data_bm['Date'][D][0:4]
    m=data_bm['Date'][D][5:7]
    d=data_bm['Date'][D][8:10]
    YMD=y+m+d
    if(data_bm['Date'][D]==data_bm['Date'][D+1]):
        won=int(data_bm['Won'][D]+data_bm['Won'][D+1])
        new_data=[YMD, won]
        data_bm_sum.loc[D]=new_data
    else:
        new_data=[YMD, int(data_bm['Won'][D])]
        data_bm_sum.loc[D]=new_data

for D in range(len(data_bm_sum)):
    try:
        if(data_bm_sum['Date'][D]==data_bm_sum['Date'][D+1]):
            data_bm_sum=data_bm_sum.drop(D+1, axis=0)

    except KeyError:
        pass
    
print(data_bm_sum)
data_bm_sum = data_bm_sum.reset_index(drop=True)
data_bm_sum.to_csv('./Data/배달의 민족_2021년_수익정산_동일날짜합.csv', encoding='cp949')
# Out:
#          Date      Won
# 0    20210104   249789
# 2    20210105   211252
# 3    20210106   152762
# 5    20210107  1310714
# 7    20210108   252126
# ..        ...      ...
# 418  20211123    48750
# 420  20211124   123086
# 422  20211125   572818
# 424  20211125     4835
# 425  20211126    98345
#
# [260 rows x 2 columns]

# %% [markdown]
# #### 서울시 기상 정보 저장

# %%
data_weather = pd.read_excel('./Original_Data/OBS_ASOS_DD_20211123223955.xlsx')
data_weather = data_weather.iloc[:, [2,3,5,6]]
data_weather.insert(2, '강수여부', 1) # 컬럼 새로 생성 후 우선은 다 비오는 경우인 '1'로 입력

for num in range(len(data_weather)):
    rain_values = data_weather.iloc[num, [3]].values[0] # 강수량 컬럼의 정보를 읽어옴
    if (str(rain_values)=='nan' or float(rain_values)==0.0):
        data_weather['강수여부'][num]=0 # 맑은 날은 0으로 값 변경
        data_weather['일강수량(mm)'][num]=0
        
data_weather = data_weather.reset_index(drop=True) # 인덱스 초기화
data_weather.to_csv('./Data/2021_서울_기상정보.csv', encoding='cp949')
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12860/2957362069.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_weather['강수여부'][num]=0 # 맑은 날은 0으로 값 변경
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12860/2957362069.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_weather['일강수량(mm)'][num]=0

# %% [markdown]
# #### 전국 Covid 정보 저장

# %%
data_covid = pd.read_excel('./Original_Data/코로나 현황.xlsx')
start_date=int(data_covid.loc[data_covid['날짜'] == 20210101].index[0])
data_covid = data_covid.iloc[start_date:, [0,1,4]]
data_covid = data_covid.reset_index(drop=True) # 인덱스 초기화
data_covid.to_csv('./Data/2021_KOREA_Covid.csv', encoding='cp949')

# %% [markdown]
# #### 거리두기 규제 및 집합 인원수 컬럼 추가

# %%
data_covid=pd.read_csv('./Data/2021_KOREA_Covid.csv', encoding='cp949')

data_covid['18시 전 규제 인원수']=np.NaN
data_covid['18시 후 규제 인원수']=np.NaN
data_covid['영업 제한 시각']=np.NaN

covid_rules={20210101: [5,5,21], 20210121: [5,5,21], 20210215: [5,5,22], 20210701: [9,9,24], 20210712: [5,3,24], 20211018: [9,9,24], 20211101: [10,10,27]}
# 시간 제한이 사라진 이후는 24시 이후 영업의 의미를 담기 위해 27로 설정.

for D in range (len(data_covid)):
    date=int(data_covid['날짜'][D])
    
    try:
        rules=covid_rules[date]
    except KeyError:
        rules=rules
    
    data_covid['18시 전 규제 인원수'][D]=rules[0]
    data_covid['18시 후 규제 인원수'][D]=rules[1]
    data_covid['영업 제한 시각'][D]=rules[2]
    
data_covid=data_covid.astype(int)
data_covid = data_covid.drop([data_covid.columns[0]], axis=1)
print(data_covid)
data_covid.to_csv('./Data/2021_KOREA_Covid+.csv', encoding='cp949')
# Out:
#            날짜  확진자수(양성)       검사수  18시 전 규제 인원수  18시 후 규제 인원수  영업 제한 시각
# 0    20210101     61753   4269308             5             5        21
# 1    20210102     62573   4302790             5             5        21
# 2    20210103     63230   4340830             5             5        21
# 3    20210104     64250   4376600             5             5        21
# 4    20210105     64964   4439352             5             5        21
# ..        ...       ...       ...           ...           ...       ...
# 322  20211119    409099  15848464            10            10        27
# 323  20211120    412305  15851670            10            10        27
# 324  20211121    415425  15854790            10            10        27
# 325  20211122    418252  15857617            10            10        27
# 326  20211123    420950  15860315            10            10        27
#
# [327 rows x 6 columns]
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16764/1539669511.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_covid['18시 전 규제 인원수'][D]=rules[0]
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16764/1539669511.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_covid['18시 후 규제 인원수'][D]=rules[1]
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16764/1539669511.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_covid['영업 제한 시각'][D]=rules[2]

# %%
Data_bm=pd.read_csv('./Data/배달의 민족_2021년_수익정산_동일날짜합.csv', encoding='cp949')
Data_weather=pd.read_csv('./Data/2021_서울_기상정보.csv', encoding='cp949')
Data_covid=pd.read_csv('./Data/2021_KOREA_Covid+.csv', encoding='cp949')

Data_weather2=Data_weather.iloc[:,[2,3,4,5]]
Data_bm2=Data_bm.iloc[:, [1,2]]

# %%
Data_C_W = pd.concat([Data_covid, Data_weather2],axis=1)
Data_C_W=Data_C_W[:-1] # 날씨 데이터는 11/23 데이터가 없기 때문에 맨 마지막 row 삭제

# %%
Data_C_W['Won']=0

C1=0
C2=0
      
while(True):
    try:
        if(int(Data_C_W['날짜'][C1])==int(Data_bm2['Date'][C2])):
            Data_C_W['Won'][C1]=Data_bm2['Won'][C2]
            C1+=1
            C2+=1

        if(int(Data_C_W['날짜'][C1])>int(Data_bm2['Date'][C2])):
            C2+=1

        if(int(Data_C_W['날짜'][C1])<int(Data_bm2['Date'][C2])):
            C1+=1
            
    except:
        break
        
Data_C_W_B=Data_C_W
Data_C_W_B = Data_C_W_B.drop([Data_C_W_B.columns[0]], axis=1)
Data_C_W_B.to_csv('./Data/2021_Data_Combined.csv', encoding='cp949')
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12860/754528038.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_C_W['Won'][C1]=Data_bm2['Won'][C2]

# %%
Data_Combined=pd.read_csv('./Data/2021_Data_Combined.csv', encoding='cp949')

# %%
Data_Combined
# Out:
#      Unnamed: 0        날짜  확진자수(양성)       검사수  18시 전 규제 인원수  18시 후 규제 인원수  \
# 0             0  20210101     61753   4269308             5             5
# 1             1  20210102     62573   4302790             5             5
# 2             2  20210103     63230   4340830             5             5
# 3             3  20210104     64250   4376600             5             5
# 4             4  20210105     64964   4439352             5             5
# ..          ...       ...       ...       ...           ...           ...
# 321         321  20211118    406065  15845430            10            10
# 322         322  20211119    409099  15848464            10            10
# 323         323  20211120    412305  15851670            10            10
# 324         324  20211121    415425  15854790            10            10
# 325         325  20211122    418252  15857617            10            10
#
#      영업 제한 시각  평균기온(°C)  강수여부  일강수량(mm)  평균 풍속(m/s)     Won
# 0          21      -4.2   0.0       0.0         2.0       0
# 1          21      -5.0   0.0       0.0         2.6       0
# 2          21      -5.6   0.0       0.0         2.0       0
# 3          21      -3.5   0.0       0.0         1.7  249789
# 4          21      -5.5   0.0       0.0         2.9  211252
# ..        ...       ...   ...       ...         ...     ...
# 321        27      11.9   0.0       0.0         2.4  322402
# 322        27      12.9   0.0       0.0         1.9   55371
# 323        27      10.4   0.0       0.0         1.6       0
# 324        27      10.4   1.0       5.9         1.9       0
# 325        27       2.7   1.0       1.3         4.1   68641
#
# [326 rows x 12 columns]

# %% [markdown]
# ### 4. 데이터 정규화

# %% [markdown]
# #### Min-Max Scaling 이용, 4년치 학습 데이터 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

# 정규화 과정을 거쳐 데이터 범위를 원하는 범위로 제한. 그래프는 동일하나 손실 정도를 확인하기에 더 좋음.
# 배치 정규화는 기울기 소멸 문제를 해결하기는 좋으나, RNN의 경우 계층별로 미니 정규화 적용이 필요해 모델이 복잡해지고 효율이 저하됨.
Data_Combined.sort_index(ascending=False).reset_index(drop=True)

scaler = MinMaxScaler()
scale_cols = ['확진자수(양성)', '검사수', '18시 전 규제 인원수', '18시 후 규제 인원수', '영업 제한 시각', '평균기온(°C)', '강수여부', '일강수량(mm)', '평균 풍속(m/s)', 'Won']
Data_scaled = scaler.fit_transform(Data_Combined[scale_cols])
Data_scaled = pd.DataFrame(Data_scaled)
Data_scaled.columns = scale_cols

Data_scaled.insert(0, '날짜', Data_Combined['날짜'])
Data_scaled
# Out:
#            날짜  확진자수(양성)       검사수  18시 전 규제 인원수  18시 후 규제 인원수  영업 제한 시각  \
# 0    20210101  0.000000  0.000000           0.0      0.285714       0.0
# 1    20210102  0.002300  0.002889           0.0      0.285714       0.0
# 2    20210103  0.004143  0.006172           0.0      0.285714       0.0
# 3    20210104  0.007004  0.009259           0.0      0.285714       0.0
# 4    20210105  0.009007  0.014674           0.0      0.285714       0.0
# ..        ...       ...       ...           ...           ...       ...
# 321  20211118  0.965815  0.998948           1.0      1.000000       1.0
# 322  20211119  0.974325  0.999210           1.0      1.000000       1.0
# 323  20211120  0.983318  0.999487           1.0      1.000000       1.0
# 324  20211121  0.992070  0.999756           1.0      1.000000       1.0
# 325  20211122  1.000000  1.000000           1.0      1.000000       1.0
#
#      평균기온(°C)  강수여부  일강수량(mm)  평균 풍속(m/s)       Won
# 0    0.229614   0.0  0.000000    0.189189  0.000000
# 1    0.212446   0.0  0.000000    0.351351  0.000000
# 2    0.199571   0.0  0.000000    0.189189  0.000000
# 3    0.244635   0.0  0.000000    0.108108  0.190575
# 4    0.201717   0.0  0.000000    0.432432  0.161173
# ..        ...   ...       ...         ...       ...
# 321  0.575107   0.0  0.000000    0.297297  0.245974
# 322  0.596567   0.0  0.000000    0.162162  0.042245
# 323  0.542918   0.0  0.000000    0.081081  0.000000
# 324  0.542918   1.0  0.076227    0.162162  0.000000
# 325  0.377682   1.0  0.016796    0.756757  0.052369
#
# [326 rows x 11 columns]

# %% [markdown]
# ### 5. 데이터 연관성 분석

# %%
Data_scaled.columns
# Out:
# Index(['날짜', '확진자수(양성)', '검사수', '18시 전 규제 인원수', '18시 후 규제 인원수', '영업 제한 시각',
#        '평균기온(°C)', '강수여부', '일강수량(mm)', '평균 풍속(m/s)', 'Won'],
#       dtype='object')

# %%
import scipy.stats as stats

# 피어슨 stat을 이용하면 피어슨 상관계수와 p-value값이 출력되는데 상관계수는 양 or 음의 비례관계 정도를, p-value는 상관 정도를 보여준다. (0에 가까울수록 영향이 크다.)
def P_value(dataset, c1, c2):
    Correlation=stats.pearsonr(dataset[c1], dataset[c2])
    print('< '+c1+'-'+c2+' >')
    print('P-value ==>> %.3f\n' %Correlation[1])

for p in range(1, len(Data_scaled.columns)-1):
    P_value(Data_scaled, Data_scaled.columns[p], 'Won')
# Out:
# < 확진자수(양성)-Won >
# P-value ==>> 0.093
#
# < 검사수-Won >
# P-value ==>> 0.029
#
# < 18시 전 규제 인원수-Won >
# P-value ==>> 0.284
#
# < 18시 후 규제 인원수-Won >
# P-value ==>> 0.678
#
# < 영업 제한 시각-Won >
# P-value ==>> 0.073
#
# < 평균기온(°C)-Won >
# P-value ==>> 0.006
#
# < 강수여부-Won >
# P-value ==>> 0.061
#
# < 일강수량(mm)-Won >
# P-value ==>> 0.027
#
# < 평균 풍속(m/s)-Won >
# P-value ==>> 0.783

# %%
Data_P = Data_scaled.drop(
    [Data_scaled.columns[1], Data_scaled.columns[3], Data_scaled.columns[4], Data_scaled.columns[5], Data_scaled.columns[7], Data_scaled.columns[9]], axis=1)

# %%
Data_P
# Out:
#            날짜       검사수  평균기온(°C)  일강수량(mm)       Won
# 0    20210101  0.000000  0.229614  0.000000  0.000000
# 1    20210102  0.002889  0.212446  0.000000  0.000000
# 2    20210103  0.006172  0.199571  0.000000  0.000000
# 3    20210104  0.009259  0.244635  0.000000  0.190575
# 4    20210105  0.014674  0.201717  0.000000  0.161173
# ..        ...       ...       ...       ...       ...
# 321  20211118  0.998948  0.575107  0.000000  0.245974
# 322  20211119  0.999210  0.596567  0.000000  0.042245
# 323  20211120  0.999487  0.542918  0.000000  0.000000
# 324  20211121  0.999756  0.542918  0.076227  0.000000
# 325  20211122  1.000000  0.377682  0.016796  0.052369
#
# [326 rows x 5 columns]

# %% [markdown]
# ### 7. 데이터셋 편집

# %%
TEST_SIZE = 30 # 1년치를 테스트셋으로 사용
WINDOW_SIZE = 1 # 얼마 동안의 과거 기반의 데이터에 기반하여 다음날의 값을 예측할 것인지 설정. 1=1시간을 의미

train = Data_P[:-TEST_SIZE]
test= Data_P[-TEST_SIZE:]

# %%
from sklearn.model_selection import train_test_split

feature_cols = ['검사수', '평균기온(°C)', '일강수량(mm)', 'Won']
label_cols = ['Won']

train_feature = train[feature_cols]
train_label = train[label_cols]

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, random_state=0, shuffle=False)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=1
BATCH_SIZE=128

# %%
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, False) # 학습도 셔플 안해야 맞는게 아닌가??
valid_data = windowed_dataset(y_valid, WINDOW_SIZE, BATCH_SIZE, False)

# %%
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (128, 1, 1, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (128, 1, 1)

# %% [markdown]
# ### 8. 딥러닝 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
from keras.layers.wrappers import TimeDistributed
from tensorflow.keras.utils import plot_model
import keras
    
model = Sequential([
    Conv1D(filters=64, kernel_size=5, padding="causal",activation="relu", input_shape=[WINDOW_SIZE, 1]),
    TimeDistributed(Dense(64)),
    LSTM(256, activation='relu',return_sequences=True),
    Bidirectional(LSTM(128, activation='ReLU', return_sequences=True), merge_mode='concat'),
    LSTM(128, activation='relu',return_sequences=True),
    Bidirectional(LSTM(64, activation='ReLU', return_sequences=True), merge_mode='concat'),
    LSTM(128, activation='ReLU', return_sequences = True),
    Bidirectional(LSTM(32, activation='ReLU', return_sequences=True), merge_mode='concat'),
    LSTM(32, activation='ReLU', return_sequences = False),
    Dense(1, activation='sigmoid')
                    ])

model.summary()
model.compile(loss='mean_squared_error', optimizer='Nadam')
# Out:
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_37 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 1, 64)             384
#
#  time_distributed_5 (TimeDis  (None, 1, 64)            4160
#  tributed)
#
#  lstm_31 (LSTM)              (None, 1, 256)            328704
#
#  bidirectional_13 (Bidirecti  (None, 1, 256)           394240
#  onal)
#
#  lstm_33 (LSTM)              (None, 1, 128)            197120
#
#  bidirectional_14 (Bidirecti  (None, 1, 128)           98816
#  onal)
#
#  lstm_35 (LSTM)              (None, 1, 128)            131584
#
#  bidirectional_15 (Bidirecti  (None, 1, 64)            41216
#  onal)
#
#  lstm_37 (LSTM)              (None, 32)                12416
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,208,673
# Trainable params: 1,208,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Plot model 저장

# %%
from keras.utils.vis_utils import plot_model
import pydot
import pydotplus
import graphviz

plot_model(model, to_file='./Result/CNN+LSTM/model.png')
plot_model(model, to_file='./Result/CNN+LSTM/model_shapes.png', show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_872/3599171036.py in <module>
#       1 from keras.utils.vis_utils import plot_model
# ----> 2 import pydot
#       3 import pydotplus
#       4 import graphviz
#       5
#
# ModuleNotFoundError: No module named 'pydot'

# %% [markdown]
# #### 학습

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20)

with tf.device('/GPU:0'):
    model_path = 'model'
    filename = os.path.join(model_path, 'tmp_checkpoint_Covid.h5')
    checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    history = model.fit(train_data, epochs=100, batch_size=32,validation_data=(valid_data), callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/100
#       2/Unknown - 8s 76ms/step - loss: 0.1803
# Epoch 00001: val_loss improved from inf to 0.18275, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 9s 1s/step - loss: 0.1803 - val_loss: 0.1828
# Epoch 2/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1798
# Epoch 00002: val_loss improved from 0.18275 to 0.18229, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 195ms/step - loss: 0.1798 - val_loss: 0.1823
# Epoch 3/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1793
# Epoch 00003: val_loss improved from 0.18229 to 0.18180, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 186ms/step - loss: 0.1793 - val_loss: 0.1818
# Epoch 4/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1788
# Epoch 00004: val_loss improved from 0.18180 to 0.18128, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 195ms/step - loss: 0.1788 - val_loss: 0.1813
# Epoch 5/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1783
# Epoch 00005: val_loss improved from 0.18128 to 0.18069, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 189ms/step - loss: 0.1783 - val_loss: 0.1807
# Epoch 6/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1777
# Epoch 00006: val_loss improved from 0.18069 to 0.18005, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 181ms/step - loss: 0.1777 - val_loss: 0.1800
# Epoch 7/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1771
# Epoch 00007: val_loss improved from 0.18005 to 0.17936, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 186ms/step - loss: 0.1771 - val_loss: 0.1794
# Epoch 8/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1764
# Epoch 00008: val_loss improved from 0.17936 to 0.17862, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 197ms/step - loss: 0.1764 - val_loss: 0.1786
# Epoch 9/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1756
# Epoch 00009: val_loss improved from 0.17862 to 0.17781, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.1756 - val_loss: 0.1778
# Epoch 10/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1748
# Epoch 00010: val_loss improved from 0.17781 to 0.17693, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 216ms/step - loss: 0.1748 - val_loss: 0.1769
# Epoch 11/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1739
# Epoch 00011: val_loss improved from 0.17693 to 0.17596, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 212ms/step - loss: 0.1739 - val_loss: 0.1760
# Epoch 12/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1729
# Epoch 00012: val_loss improved from 0.17596 to 0.17487, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 203ms/step - loss: 0.1729 - val_loss: 0.1749
# Epoch 13/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1718
# Epoch 00013: val_loss improved from 0.17487 to 0.17362, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 183ms/step - loss: 0.1718 - val_loss: 0.1736
# Epoch 14/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1705
# Epoch 00014: val_loss improved from 0.17362 to 0.17215, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 187ms/step - loss: 0.1705 - val_loss: 0.1722
# Epoch 15/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1690
# Epoch 00015: val_loss improved from 0.17215 to 0.17035, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.1690 - val_loss: 0.1703
# Epoch 16/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1671
# Epoch 00016: val_loss improved from 0.17035 to 0.16800, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.1671 - val_loss: 0.1680
# Epoch 17/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1646
# Epoch 00017: val_loss improved from 0.16800 to 0.16447, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 196ms/step - loss: 0.1646 - val_loss: 0.1645
# Epoch 18/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1605
# Epoch 00018: val_loss improved from 0.16447 to 0.15748, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 198ms/step - loss: 0.1605 - val_loss: 0.1575
# Epoch 19/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1514
# Epoch 00019: val_loss improved from 0.15748 to 0.13279, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 189ms/step - loss: 0.1514 - val_loss: 0.1328
# Epoch 20/100
# 2/2 [==============================] - ETA: 0s - loss: 0.1067
# Epoch 00020: val_loss improved from 0.13279 to 0.02331, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 185ms/step - loss: 0.1067 - val_loss: 0.0233
# Epoch 21/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 00021: val_loss did not improve from 0.02331
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0246 - val_loss: 0.0238
# Epoch 22/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 00022: val_loss improved from 0.02331 to 0.02229, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0247 - val_loss: 0.0223
# Epoch 23/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 00023: val_loss did not improve from 0.02229
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0249 - val_loss: 0.0253
# Epoch 24/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0260
# Epoch 00024: val_loss improved from 0.02229 to 0.02109, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0260 - val_loss: 0.0211
# Epoch 25/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0250
# Epoch 00025: val_loss did not improve from 0.02109
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0250 - val_loss: 0.0252
# Epoch 26/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0259
# Epoch 00026: val_loss improved from 0.02109 to 0.02086, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0259 - val_loss: 0.0209
# Epoch 27/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 00027: val_loss did not improve from 0.02086
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0244 - val_loss: 0.0240
# Epoch 28/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 00028: val_loss improved from 0.02086 to 0.02019, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 201ms/step - loss: 0.0245 - val_loss: 0.0202
# Epoch 29/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0237
# Epoch 00029: val_loss did not improve from 0.02019
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0237 - val_loss: 0.0233
# Epoch 30/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0239
# Epoch 00030: val_loss improved from 0.02019 to 0.02016, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0239 - val_loss: 0.0202
# Epoch 31/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 00031: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0233 - val_loss: 0.0224
# Epoch 32/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0234
# Epoch 00032: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0234 - val_loss: 0.0203
# Epoch 33/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 00033: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0230 - val_loss: 0.0216
# Epoch 34/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 00034: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0231 - val_loss: 0.0204
# Epoch 35/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 00035: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0227 - val_loss: 0.0210
# Epoch 36/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 00036: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0227 - val_loss: 0.0204
# Epoch 37/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 00037: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0225 - val_loss: 0.0205
# Epoch 38/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 00038: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0224 - val_loss: 0.0203
# Epoch 39/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0222
# Epoch 00039: val_loss did not improve from 0.02016
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 40/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0221
# Epoch 00040: val_loss improved from 0.02016 to 0.02009, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0221 - val_loss: 0.0201
# Epoch 41/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 00041: val_loss improved from 0.02009 to 0.02000, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 195ms/step - loss: 0.0220 - val_loss: 0.0200
# Epoch 42/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 00042: val_loss improved from 0.02000 to 0.01990, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0219 - val_loss: 0.0199
# Epoch 43/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 00043: val_loss improved from 0.01990 to 0.01981, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0218 - val_loss: 0.0198
# Epoch 44/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0217
# Epoch 00044: val_loss improved from 0.01981 to 0.01972, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 200ms/step - loss: 0.0217 - val_loss: 0.0197
# Epoch 45/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 00045: val_loss improved from 0.01972 to 0.01964, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0216 - val_loss: 0.0196
# Epoch 46/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 00046: val_loss improved from 0.01964 to 0.01956, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0215 - val_loss: 0.0196
# Epoch 47/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0214
# Epoch 00047: val_loss improved from 0.01956 to 0.01948, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0214 - val_loss: 0.0195
# Epoch 48/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 00048: val_loss improved from 0.01948 to 0.01941, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0213 - val_loss: 0.0194
# Epoch 49/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0212
# Epoch 00049: val_loss improved from 0.01941 to 0.01935, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0212 - val_loss: 0.0193
# Epoch 50/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 00050: val_loss improved from 0.01935 to 0.01929, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0211 - val_loss: 0.0193
# Epoch 51/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 00051: val_loss improved from 0.01929 to 0.01923, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0211 - val_loss: 0.0192
# Epoch 52/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 00052: val_loss improved from 0.01923 to 0.01917, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0210 - val_loss: 0.0192
# Epoch 53/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0209
# Epoch 00053: val_loss improved from 0.01917 to 0.01912, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0209 - val_loss: 0.0191
# Epoch 54/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0209
# Epoch 00054: val_loss improved from 0.01912 to 0.01907, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0209 - val_loss: 0.0191
# Epoch 55/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0208
# Epoch 00055: val_loss improved from 0.01907 to 0.01903, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0208 - val_loss: 0.0190
# Epoch 56/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 00056: val_loss improved from 0.01903 to 0.01898, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0207 - val_loss: 0.0190
# Epoch 57/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 00057: val_loss improved from 0.01898 to 0.01894, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0207 - val_loss: 0.0189
# Epoch 58/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0206
# Epoch 00058: val_loss improved from 0.01894 to 0.01890, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0206 - val_loss: 0.0189
# Epoch 59/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0206
# Epoch 00059: val_loss improved from 0.01890 to 0.01887, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0206 - val_loss: 0.0189
# Epoch 60/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 00060: val_loss improved from 0.01887 to 0.01883, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0205 - val_loss: 0.0188
# Epoch 61/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 00061: val_loss improved from 0.01883 to 0.01880, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0205 - val_loss: 0.0188
# Epoch 62/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 00062: val_loss improved from 0.01880 to 0.01877, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0204 - val_loss: 0.0188
# Epoch 63/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 00063: val_loss improved from 0.01877 to 0.01874, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0204 - val_loss: 0.0187
# Epoch 64/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 00064: val_loss improved from 0.01874 to 0.01871, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 207ms/step - loss: 0.0203 - val_loss: 0.0187
# Epoch 65/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 00065: val_loss improved from 0.01871 to 0.01869, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0203 - val_loss: 0.0187
# Epoch 66/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 00066: val_loss improved from 0.01869 to 0.01866, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0203 - val_loss: 0.0187
# Epoch 67/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 00067: val_loss improved from 0.01866 to 0.01864, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0202 - val_loss: 0.0186
# Epoch 68/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 00068: val_loss improved from 0.01864 to 0.01862, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0202 - val_loss: 0.0186
# Epoch 69/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 00069: val_loss improved from 0.01862 to 0.01860, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 205ms/step - loss: 0.0202 - val_loss: 0.0186
# Epoch 70/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 00070: val_loss improved from 0.01860 to 0.01858, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0201 - val_loss: 0.0186
# Epoch 71/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 00071: val_loss improved from 0.01858 to 0.01856, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 207ms/step - loss: 0.0201 - val_loss: 0.0186
# Epoch 72/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 00072: val_loss improved from 0.01856 to 0.01855, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0201 - val_loss: 0.0185
# Epoch 73/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 00073: val_loss improved from 0.01855 to 0.01853, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0200 - val_loss: 0.0185
# Epoch 74/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 00074: val_loss improved from 0.01853 to 0.01851, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0200 - val_loss: 0.0185
# Epoch 75/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 00075: val_loss improved from 0.01851 to 0.01850, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0200 - val_loss: 0.0185
# Epoch 76/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 00076: val_loss improved from 0.01850 to 0.01849, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0200 - val_loss: 0.0185
# Epoch 77/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0199
# Epoch 00077: val_loss improved from 0.01849 to 0.01847, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0199 - val_loss: 0.0185
# Epoch 78/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0199
# Epoch 00078: val_loss improved from 0.01847 to 0.01846, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 204ms/step - loss: 0.0199 - val_loss: 0.0185
# Epoch 79/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0199
# Epoch 00079: val_loss improved from 0.01846 to 0.01845, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0199 - val_loss: 0.0184
# Epoch 80/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0199
# Epoch 00080: val_loss improved from 0.01845 to 0.01844, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0199 - val_loss: 0.0184
# Epoch 81/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 00081: val_loss improved from 0.01844 to 0.01843, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0198 - val_loss: 0.0184
# Epoch 82/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 00082: val_loss improved from 0.01843 to 0.01842, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0198 - val_loss: 0.0184
# Epoch 83/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 00083: val_loss improved from 0.01842 to 0.01841, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0198 - val_loss: 0.0184
# Epoch 84/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 00084: val_loss improved from 0.01841 to 0.01840, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0198 - val_loss: 0.0184
# Epoch 85/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 00085: val_loss improved from 0.01840 to 0.01839, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0198 - val_loss: 0.0184
# Epoch 86/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 00086: val_loss improved from 0.01839 to 0.01839, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0197 - val_loss: 0.0184
# Epoch 87/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 00087: val_loss improved from 0.01839 to 0.01838, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0197 - val_loss: 0.0184
# Epoch 88/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 00088: val_loss improved from 0.01838 to 0.01837, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0197 - val_loss: 0.0184
# Epoch 89/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 00089: val_loss improved from 0.01837 to 0.01837, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0197 - val_loss: 0.0184
# Epoch 90/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 00090: val_loss improved from 0.01837 to 0.01836, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0197 - val_loss: 0.0184
# Epoch 91/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 00091: val_loss improved from 0.01836 to 0.01835, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0197 - val_loss: 0.0184
# Epoch 92/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00092: val_loss improved from 0.01835 to 0.01835, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 93/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00093: val_loss improved from 0.01835 to 0.01834, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 94/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00094: val_loss improved from 0.01834 to 0.01834, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 95/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00095: val_loss improved from 0.01834 to 0.01833, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 96/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00096: val_loss improved from 0.01833 to 0.01833, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 97/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00097: val_loss improved from 0.01833 to 0.01832, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 98/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00098: val_loss improved from 0.01832 to 0.01832, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 99/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 00099: val_loss improved from 0.01832 to 0.01831, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0196 - val_loss: 0.0183
# Epoch 100/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0195
# Epoch 00100: val_loss improved from 0.01831 to 0.01831, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0195 - val_loss: 0.0183

# %%
model.load_weights(filename)
pred = model.predict(test['Won'])

pred.shape
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FCB946BB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (30, 1)

# %% [markdown]
# ### 9. 결과 표시

# %%
try:
    os.mkdir('./Result')
    print('폴더 생성 완료.')
    
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.')
# Out:
# 해당 폴더가 이미 존재합니다.

# %%
try:
    os.mkdir('./Result/CNN+LSTM')
    os.mkdir('./Result/CNN+LSTM/Graph')
    os.mkdir('./Result/CNN+LSTM/Data')
    print('폴더 생성 완료.')
    
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.')
# Out:
# 해당 폴더가 이미 존재합니다.

# %%
plt.title('Model Validation Loss', size='15')
plt.xlabel('Epoch')
plt.ylabel('Val_loss')
plt.grid(True)
plt.plot(history.history['val_loss'])
plt.savefig('./Result/CNN+LSTM/Graph/Model_Valdation_Loss.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 성능 측정 지표

# %%
from sklearn.metrics import r2_score as r2
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_squared_log_error as MSLE

print('r2 >> %.4f' %r2(test['Won'], pred)) # 1에 가까워야 좋음
print('MAE >> %.4f' %MAE(test['Won'], pred)) # 0에 가까워야 좋음
print('MSE >> %.4f' %MSE(test['Won'], pred)) # 0에 가까워야 좋음
print('RMSE >> %.4f' %np.sqrt(MSE(test['Won'], pred))) # 0에 가까워야 좋음
#print('RMSLE >> %.4f' %np.sqrt(MSLE(test['Won'], pred))) # 0에 가까워야 좋음
# Out:
# r2 >> -0.0802
# MAE >> 0.0748
# MSE >> 0.0109
# RMSE >> 0.1046

# %%
RMSE = np.sqrt(MSE(test['Won'], pred))
RMSE_pct = round(1-RMSE, 5)*100
print('RMSE 측정 정확도 ==>> %.3f %%' %RMSE_pct)
# Out:
# RMSE 측정 정확도 ==>> 89.539 %
