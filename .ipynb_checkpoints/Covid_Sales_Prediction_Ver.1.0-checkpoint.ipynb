# %% [markdown]
# # Covid Sales Prediction

# %% [markdown]
# ### 목차

# %%
"""
1. 모듈 임포트

2. 데이터 처리

3. 그래프 확인

4. 데이터 정규화 

5. 데이터 연관성 분석

6. 이상치 처리
    -이상치 확인 함수 생성
    -분위별 이상치 1차 검색
    -이상치 치환
    -처리 후 잔여 개수 확인

7. 데이터셋 편집

8. 딥러닝 모델

9. 결과 표시
    -그래프 표시
    -그래프 비교 결과
    -성능 측정 지표

10. 예측값과 실제값 결과 csv 파일 저장
"""
# Out:
# '\n1. 모듈 임포트\n\n2. 데이터 처리\n\n3. 그래프 확인\n\n4. 데이터 정규화 \n\n5. 데이터 연관성 분석\n\n6. 이상치 처리\n    -이상치 확인 함수 생성\n    -분위별 이상치 1차 검색\n    -이상치 치환\n    -처리 후 잔여 개수 확인\n\n7. 데이터셋 편집\n\n8. 딥러닝 모델\n\n9. 결과 표시\n    -그래프 표시\n    -그래프 비교 결과\n    -성능 측정 지표\n\n10. 예측값과 실제값 결과 csv 파일 저장\n'

# %% [markdown]
# ### <화면 가로 확장>

# %%
# 화면 가로 확장 코드 (기본 width 50%)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### 1. 모듈 임포트

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import tensorflow as tf
import csv
import os
import datetime

# %% [markdown]
# ### <GPU 확인>

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### 2. 데이터

# %% [markdown]
# #### 배달의 민족 월별 정산 데이터 저장

# %%
try:
    os.mkdir('./Data')
    os.mkdir('./Data/BaeMin')
    print('폴더 생성 완료.')
    
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.')
# Out:
# 폴더 생성 완료.

# %%
for BM in range(1, len(os.listdir('./Original_Data/BaeMin'))+1):
    if BM<7:
        count_num='0'+str(BM)
        data_bm = pd.read_excel('./Original_Data/BaeMin/배달의민족-2021년'+count_num+'월_정산명세서_성정환사장님.xlsx', sheet_name='상세')
        data_bm = data_bm.iloc[3:, [0, 20]] # 행, 열 제한으로 필요 정보 추출
    if (BM>=7 and BM<10):
        count_num='0'+str(BM)
        data_bm = pd.read_excel('./Original_Data/BaeMin/배달의민족-2021년'+count_num+'월_정산명세서_성정환사장님.xlsx', sheet_name='상세')
        data_bm = data_bm.iloc[3:, [0, 21]] # 행, 열 제한으로 필요 정보 추출
    if BM>=10:
        count_num=str(BM)
        data_bm = pd.read_excel('./Original_Data/BaeMin/배달의민족-2021년'+count_num+'월_정산명세서_성정환사장님.xlsx', sheet_name='상세')
        data_bm = data_bm.iloc[3:, [0, 21]] 
    
    data_bm = data_bm.reset_index(drop=True) # 인덱스 초기화
    data_bm.to_csv('./Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv', header=False, encoding='cp949')
    data_bm_named=pd.read_csv('./Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv', names=['Date','Won'], encoding='cp949')
    data_bm_named.to_csv('./Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv', encoding='cp949')

# %%
# 1년 단위 파일로 병합
bm_y = pd.DataFrame()
for y in range(1, len(os.listdir('./Data/BaeMin'))+1):
    if y<=9:
        count_num='0'+str(y)
    else:
        count_num=str(y)
        
    file = './Data/BaeMin/배달의 민족_2021년_'+count_num+'월_수익정산.csv'
    bm_m= pd.read_csv(file, encoding='cp949')
    bm_y = pd.concat([bm_y, bm_m])
    
bm_y = bm_y.drop([bm_y.columns[0]], axis=1)
bm_y = bm_y.reset_index(drop=True)
bm_y.to_csv('./Data/배달의 민족_2021년_수익정산.csv', encoding='cp949')

# 중간에 0이 있는데 코로나 때문에 0이 된게 아니라면 이상치 처리를 해야함.

# %%
data_bm_sum=pd.DataFrame(columns=['Date','Won'])
data_bm=pd.read_csv('./Data/배달의 민족_2021년_수익정산.csv', encoding='cp949')
data_bm = data_bm.drop([data_bm.columns[0]], axis=1)

for D in range(len(data_bm)-1):
    y=data_bm['Date'][D][0:4]
    m=data_bm['Date'][D][5:7]
    d=data_bm['Date'][D][8:10]
    YMD=y+m+d
    if(data_bm['Date'][D]==data_bm['Date'][D+1]):
        won=int(data_bm['Won'][D]+data_bm['Won'][D+1])
        new_data=[YMD, won]
        data_bm_sum.loc[D]=new_data
    else:
        new_data=[YMD, int(data_bm['Won'][D])]
        data_bm_sum.loc[D]=new_data

for D in range(len(data_bm_sum)):
    try:
        if(data_bm_sum['Date'][D]==data_bm_sum['Date'][D+1]):
            data_bm_sum=data_bm_sum.drop(D+1, axis=0)

    except KeyError:
        pass
    
print(data_bm_sum)
data_bm_sum = data_bm_sum.reset_index(drop=True)
data_bm_sum.to_csv('./Data/배달의 민족_2021년_수익정산_동일날짜합.csv', encoding='cp949')
# Out:
#          Date      Won
# 0    20210104   249789
# 2    20210105   211252
# 3    20210106   152762
# 5    20210107  1310714
# 7    20210108   252126
# ..        ...      ...
# 418  20211123    48750
# 420  20211124   123086
# 422  20211125   572818
# 424  20211125     4835
# 425  20211126    98345
#
# [260 rows x 2 columns]

# %% [markdown]
# #### 서울시 기상 정보 저장

# %%
data_weather = pd.read_excel('./Original_Data/OBS_ASOS_DD_20211123223955.xlsx')
data_weather = data_weather.iloc[:, [2,3,5,6]]
data_weather.insert(2, '강수여부', 1) # 컬럼 새로 생성 후 우선은 다 비오는 경우인 '1'로 입력

for num in range(len(data_weather)):
    rain_values = data_weather.iloc[num, [3]].values[0] # 강수량 컬럼의 정보를 읽어옴
    if (str(rain_values)=='nan' or float(rain_values)==0.0):
        data_weather['강수여부'][num]=0 # 맑은 날은 0으로 값 변경
        data_weather['일강수량(mm)'][num]=0
        
data_weather = data_weather.reset_index(drop=True) # 인덱스 초기화
data_weather.to_csv('./Data/2021_서울_기상정보.csv', encoding='cp949')
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12860/2957362069.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_weather['강수여부'][num]=0 # 맑은 날은 0으로 값 변경
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12860/2957362069.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_weather['일강수량(mm)'][num]=0

# %% [markdown]
# #### 전국 Covid 정보 저장

# %%
data_covid = pd.read_excel('./Original_Data/코로나 현황.xlsx')
start_date=int(data_covid.loc[data_covid['날짜'] == 20210101].index[0])
data_covid = data_covid.iloc[start_date:, [0,1,4]]
data_covid = data_covid.reset_index(drop=True) # 인덱스 초기화
data_covid.to_csv('./Data/2021_KOREA_Covid.csv', encoding='cp949')

# %% [markdown]
# #### 거리두기 규제 및 집합 인원수 컬럼 추가

# %%
data_covid=pd.read_csv('./Data/2021_KOREA_Covid.csv', encoding='cp949')

data_covid['18시 전 규제 인원수']=np.NaN
data_covid['18시 후 규제 인원수']=np.NaN
data_covid['영업 제한 시각']=np.NaN

covid_rules={20210101: [5,5,21], 20210121: [5,5,21], 20210215: [5,5,22], 20210701: [9,9,24], 20210712: [5,3,24], 20211018: [9,9,24], 20211101: [10,10,27]}
# 시간 제한이 사라진 이후는 24시 이후 영업의 의미를 담기 위해 27로 설정.

for D in range (len(data_covid)):
    date=int(data_covid['날짜'][D])
    
    try:
        rules=covid_rules[date]
    except KeyError:
        rules=rules
    
    data_covid['18시 전 규제 인원수'][D]=rules[0]
    data_covid['18시 후 규제 인원수'][D]=rules[1]
    data_covid['영업 제한 시각'][D]=rules[2]
    
data_covid=data_covid.astype(int)
data_covid = data_covid.drop([data_covid.columns[0]], axis=1)
print(data_covid)
data_covid.to_csv('./Data/2021_KOREA_Covid+.csv', encoding='cp949')
# Out:
#            날짜  확진자수(양성)       검사수  18시 전 규제 인원수  18시 후 규제 인원수  영업 제한 시각
# 0    20210101     61753   4269308             5             5        21
# 1    20210102     62573   4302790             5             5        21
# 2    20210103     63230   4340830             5             5        21
# 3    20210104     64250   4376600             5             5        21
# 4    20210105     64964   4439352             5             5        21
# ..        ...       ...       ...           ...           ...       ...
# 322  20211119    409099  15848464            10            10        27
# 323  20211120    412305  15851670            10            10        27
# 324  20211121    415425  15854790            10            10        27
# 325  20211122    418252  15857617            10            10        27
# 326  20211123    420950  15860315            10            10        27
#
# [327 rows x 6 columns]
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16764/1539669511.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_covid['18시 전 규제 인원수'][D]=rules[0]
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16764/1539669511.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_covid['18시 후 규제 인원수'][D]=rules[1]
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16764/1539669511.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_covid['영업 제한 시각'][D]=rules[2]

# %%
Data_bm=pd.read_csv('./Data/배달의 민족_2021년_수익정산_동일날짜합.csv', encoding='cp949')
Data_weather=pd.read_csv('./Data/2021_서울_기상정보.csv', encoding='cp949')
Data_covid=pd.read_csv('./Data/2021_KOREA_Covid+.csv', encoding='cp949')

Data_weather2=Data_weather.iloc[:,[2,3,4,5]]
Data_bm2=Data_bm.iloc[:, [1,2]]

# %%
Data_C_W = pd.concat([Data_covid, Data_weather2],axis=1)
Data_C_W=Data_C_W[:-1] # 날씨 데이터는 11/23 데이터가 없기 때문에 맨 마지막 row 삭제

# %%
Data_C_W['Won']=0

C1=0
C2=0
      
while(True):
    try:
        if(int(Data_C_W['날짜'][C1])==int(Data_bm2['Date'][C2])):
            Data_C_W['Won'][C1]=Data_bm2['Won'][C2]
            C1+=1
            C2+=1

        if(int(Data_C_W['날짜'][C1])>int(Data_bm2['Date'][C2])):
            C2+=1

        if(int(Data_C_W['날짜'][C1])<int(Data_bm2['Date'][C2])):
            C1+=1
            
    except:
        break
        
Data_C_W_B=Data_C_W
Data_C_W_B = Data_C_W_B.drop([Data_C_W_B.columns[0]], axis=1)
Data_C_W_B.to_csv('./Data/2021_Data_Combined.csv', encoding='cp949')
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12860/754528038.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_C_W['Won'][C1]=Data_bm2['Won'][C2]

# %%
Data_Combined=pd.read_csv('./Data/2021_Data_Combined.csv', encoding='cp949')

# %%
Data_Combined
# Out:
#      Unnamed: 0        날짜  확진자수(양성)       검사수  18시 전 규제 인원수  18시 후 규제 인원수  \
# 0             0  20210101     61753   4269308             5             5
# 1             1  20210102     62573   4302790             5             5
# 2             2  20210103     63230   4340830             5             5
# 3             3  20210104     64250   4376600             5             5
# 4             4  20210105     64964   4439352             5             5
# ..          ...       ...       ...       ...           ...           ...
# 321         321  20211118    406065  15845430            10            10
# 322         322  20211119    409099  15848464            10            10
# 323         323  20211120    412305  15851670            10            10
# 324         324  20211121    415425  15854790            10            10
# 325         325  20211122    418252  15857617            10            10
#
#      영업 제한 시각  평균기온(°C)  강수여부  일강수량(mm)  평균 풍속(m/s)     Won
# 0          21      -4.2   0.0       0.0         2.0       0
# 1          21      -5.0   0.0       0.0         2.6       0
# 2          21      -5.6   0.0       0.0         2.0       0
# 3          21      -3.5   0.0       0.0         1.7  249789
# 4          21      -5.5   0.0       0.0         2.9  211252
# ..        ...       ...   ...       ...         ...     ...
# 321        27      11.9   0.0       0.0         2.4  322402
# 322        27      12.9   0.0       0.0         1.9   55371
# 323        27      10.4   0.0       0.0         1.6       0
# 324        27      10.4   1.0       5.9         1.9       0
# 325        27       2.7   1.0       1.3         4.1   68641
#
# [326 rows x 12 columns]

# %% [markdown]
# ### 4. 데이터 정규화

# %% [markdown]
# #### Min-Max Scaling 이용, 4년치 학습 데이터 정규화

# %%
from sklearn.preprocessing import StandardScaler

# 정규화 과정을 거쳐 데이터 범위를 원하는 범위로 제한. 그래프는 동일하나 손실 정도를 확인하기에 더 좋음.
# 배치 정규화는 기울기 소멸 문제를 해결하기는 좋으나, RNN의 경우 계층별로 미니 정규화 적용이 필요해 모델이 복잡해지고 효율이 저하됨.
Data_Combined.sort_index(ascending=False).reset_index(drop=True)

scaler = StandardScaler()
scale_cols = ['확진자수(양성)', '검사수', '18시 전 규제 인원수', '18시 후 규제 인원수', '영업 제한 시각', '평균기온(°C)', '강수여부', '일강수량(mm)', '평균 풍속(m/s)', 'Won']
Data_scaled = scaler.fit_transform(Data_Combined[scale_cols])
Data_scaled = pd.DataFrame(Data_scaled)
Data_scaled.columns = scale_cols

Data_scaled.insert(0, '날짜', Data_Combined['날짜'])
Data_scaled
# Out:
#            날짜  확진자수(양성)       검사수  18시 전 규제 인원수  18시 후 규제 인원수  영업 제한 시각  \
# 0    20210101 -1.208092 -1.767536     -0.407479     -0.021171 -1.254966
# 1    20210102 -1.199875 -1.757721     -0.407479     -0.021171 -1.254966
# 2    20210103 -1.193291 -1.746570     -0.407479     -0.021171 -1.254966
# 3    20210104 -1.183069 -1.736084     -0.407479     -0.021171 -1.254966
# 4    20210105 -1.175914 -1.717689     -0.407479     -0.021171 -1.254966
# ..        ...       ...       ...           ...           ...       ...
# 321  20211118  2.242312  1.625963      2.755334      2.443732  2.598587
# 322  20211119  2.272716  1.626852      2.755334      2.443732  2.598587
# 323  20211120  2.304844  1.627792      2.755334      2.443732  2.598587
# 324  20211121  2.336110  1.628707      2.755334      2.443732  2.598587
# 325  20211122  2.364439  1.629536      2.755334      2.443732  2.598587
#
#      평균기온(°C)      강수여부  일강수량(mm)  평균 풍속(m/s)       Won
# 0   -1.951080 -0.698988 -0.316885   -0.500994 -0.710753
# 1   -2.031380 -0.698988 -0.316885    0.468288 -0.710753
# 2   -2.091606 -0.698988 -0.316885   -0.500994 -0.710753
# 3   -1.880817 -0.698988 -0.316885   -0.985635  0.724166
# 4   -2.081568 -0.698988 -0.316885    0.952929  0.502789
# ..        ...       ...       ...         ...       ...
# 321 -0.335028 -0.698988 -0.316885    0.145194  1.141293
# 322 -0.234652 -0.698988 -0.316885   -0.662541 -0.392673
# 323 -0.485592 -0.698988 -0.316885   -1.147181 -0.710753
# 324 -0.485592  1.430639  0.212468   -0.662541 -0.710753
# 325 -1.258486  1.430639 -0.200248    2.891492 -0.316443
#
# [326 rows x 11 columns]

# %% [markdown]
# ### 5. 데이터 연관성 분석

# %%
Data_scaled.columns
# Out:
# Index(['날짜', '확진자수(양성)', '검사수', '18시 전 규제 인원수', '18시 후 규제 인원수', '영업 제한 시각',
#        '평균기온(°C)', '강수여부', '일강수량(mm)', '평균 풍속(m/s)', 'Won'],
#       dtype='object')

# %%
import scipy.stats as stats

# 피어슨 stat을 이용하면 피어슨 상관계수와 p-value값이 출력되는데 상관계수는 양 or 음의 비례관계 정도를, p-value는 상관 정도를 보여준다. (0에 가까울수록 영향이 크다.)
def P_value(dataset, c1, c2):
    Correlation=stats.pearsonr(dataset[c1], dataset[c2])
    print('< '+c1+'-'+c2+' >')
    print('P-value ==>> %.3f\n' %Correlation[1])

for p in range(1, len(Data_scaled.columns)-1):
    P_value(Data_scaled, Data_scaled.columns[p], 'Won')
# Out:
# < 확진자수(양성)-Won >
# P-value ==>> 0.093
#
# < 검사수-Won >
# P-value ==>> 0.029
#
# < 18시 전 규제 인원수-Won >
# P-value ==>> 0.284
#
# < 18시 후 규제 인원수-Won >
# P-value ==>> 0.678
#
# < 영업 제한 시각-Won >
# P-value ==>> 0.073
#
# < 평균기온(°C)-Won >
# P-value ==>> 0.006
#
# < 강수여부-Won >
# P-value ==>> 0.061
#
# < 일강수량(mm)-Won >
# P-value ==>> 0.027
#
# < 평균 풍속(m/s)-Won >
# P-value ==>> 0.783

# %%
Data_P = Data_scaled.drop(
    [Data_scaled.columns[1], Data_scaled.columns[3], Data_scaled.columns[4], Data_scaled.columns[5], Data_scaled.columns[7], Data_scaled.columns[9]], axis=1)

# %%
Data_P
# Out:
#            날짜       검사수  평균기온(°C)  일강수량(mm)       Won
# 0    20210101 -1.767536 -1.951080 -0.316885 -0.710753
# 1    20210102 -1.757721 -2.031380 -0.316885 -0.710753
# 2    20210103 -1.746570 -2.091606 -0.316885 -0.710753
# 3    20210104 -1.736084 -1.880817 -0.316885  0.724166
# 4    20210105 -1.717689 -2.081568 -0.316885  0.502789
# ..        ...       ...       ...       ...       ...
# 321  20211118  1.625963 -0.335028 -0.316885  1.141293
# 322  20211119  1.626852 -0.234652 -0.316885 -0.392673
# 323  20211120  1.627792 -0.485592 -0.316885 -0.710753
# 324  20211121  1.628707 -0.485592  0.212468 -0.710753
# 325  20211122  1.629536 -1.258486 -0.200248 -0.316443
#
# [326 rows x 5 columns]

# %% [markdown]
# ### 7. 데이터셋 편집

# %%
TEST_SIZE = 30 # 1년치를 테스트셋으로 사용
WINDOW_SIZE = 1 # 얼마 동안의 과거 기반의 데이터에 기반하여 다음날의 값을 예측할 것인지 설정. 1=1시간을 의미

train = Data_P[:-TEST_SIZE]
test= Data_P[-TEST_SIZE:]

# %%
from sklearn.model_selection import train_test_split

feature_cols = ['검사수', '평균기온(°C)', '일강수량(mm)', 'Won']
label_cols = ['Won']

train_feature = train[feature_cols]
train_label = train[label_cols]

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, random_state=0, shuffle=False)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=1
BATCH_SIZE=128

# %%
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, False) # 학습도 셔플 안해야 맞는게 아닌가??
valid_data = windowed_dataset(y_valid, WINDOW_SIZE, BATCH_SIZE, False)

# %%
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (128, 1, 1, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (128, 1, 1)

# %% [markdown]
# ### 8. 딥러닝 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
from keras.layers.wrappers import TimeDistributed
from tensorflow.keras.utils import plot_model
import keras
    
model = Sequential([
    Conv1D(filters=64, kernel_size=5, padding="causal",activation="relu", input_shape=[WINDOW_SIZE, 1]),
    TimeDistributed(Dense(64)),
    LSTM(256, activation='relu',return_sequences=True),
    Bidirectional(LSTM(128, activation='ReLU', return_sequences=True), merge_mode='concat'),
    LSTM(128, activation='relu',return_sequences=True),
    Bidirectional(LSTM(64, activation='ReLU', return_sequences=True), merge_mode='concat'),
    LSTM(128, activation='ReLU', return_sequences = True),
    Bidirectional(LSTM(32, activation='ReLU', return_sequences=True), merge_mode='concat'),
    LSTM(32, activation='ReLU', return_sequences = False),
    Dense(1, activation='sigmoid')
                    ])

model.summary()
model.compile(loss='mean_squared_error', optimizer='Nadam')
# Out:
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 1, 64)             384
#
#  time_distributed_4 (TimeDis  (None, 1, 64)            4160
#  tributed)
#
#  lstm_28 (LSTM)              (None, 1, 128)            98816
#
#  bidirectional_12 (Bidirecti  (None, 1, 64)            41216
#  onal)
#
#  lstm_30 (LSTM)              (None, 32)                12416
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 157,025
# Trainable params: 157,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Plot model 저장

# %%
from keras.utils.vis_utils import plot_model
import pydot
import pydotplus
import graphviz

plot_model(model, to_file='./Result/CNN+LSTM/model.png')
plot_model(model, to_file='./Result/CNN+LSTM/model_shapes.png', show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_872/3599171036.py in <module>
#       1 from keras.utils.vis_utils import plot_model
# ----> 2 import pydot
#       3 import pydotplus
#       4 import graphviz
#       5
#
# ModuleNotFoundError: No module named 'pydot'

# %% [markdown]
# #### 학습

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20)

with tf.device('/GPU:0'):
    model_path = 'model'
    filename = os.path.join(model_path, 'tmp_checkpoint_Covid.h5')
    checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    history = model.fit(train_data, epochs=100, batch_size=32,validation_data=(valid_data), callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/100
#       1/Unknown - 3s 3s/step - loss: 1.5315
# Epoch 00001: val_loss improved from inf to 1.28285, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 4s 902ms/step - loss: 1.2761 - val_loss: 1.2829
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5310
# Epoch 00002: val_loss improved from 1.28285 to 1.28232, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 1.2756 - val_loss: 1.2823
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5307
# Epoch 00003: val_loss improved from 1.28232 to 1.28173, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 1.2750 - val_loss: 1.2817
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5303
# Epoch 00004: val_loss improved from 1.28173 to 1.28108, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 1.2745 - val_loss: 1.2811
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5298
# Epoch 00005: val_loss improved from 1.28108 to 1.28036, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 1.2739 - val_loss: 1.2804
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5293
# Epoch 00006: val_loss improved from 1.28036 to 1.27954, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 1.2732 - val_loss: 1.2795
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5288
# Epoch 00007: val_loss improved from 1.27954 to 1.27855, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 1.2724 - val_loss: 1.2786
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5281
# Epoch 00008: val_loss improved from 1.27855 to 1.27731, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 1.2714 - val_loss: 1.2773
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5272
# Epoch 00009: val_loss improved from 1.27731 to 1.27562, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 1.2702 - val_loss: 1.2756
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5260
# Epoch 00010: val_loss improved from 1.27562 to 1.27306, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 1.2685 - val_loss: 1.2731
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5242
# Epoch 00011: val_loss improved from 1.27306 to 1.26863, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 1.2659 - val_loss: 1.2686
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5210
# Epoch 00012: val_loss improved from 1.26863 to 1.25981, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 1.2613 - val_loss: 1.2598
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5145
# Epoch 00013: val_loss improved from 1.25981 to 1.23767, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2521 - val_loss: 1.2377
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4971
# Epoch 00014: val_loss improved from 1.23767 to 1.17515, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2277 - val_loss: 1.1752
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4602
# Epoch 00015: val_loss improved from 1.17515 to 1.08184, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 1.1728 - val_loss: 1.0818
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4015
# Epoch 00016: val_loss improved from 1.08184 to 0.98973, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 1.0777 - val_loss: 0.9897
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3456
# Epoch 00017: val_loss improved from 0.98973 to 0.98420, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 1.0026 - val_loss: 0.9842
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3531
# Epoch 00018: val_loss did not improve from 0.98420
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9985 - val_loss: 0.9864
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3570
# Epoch 00019: val_loss did not improve from 0.98420
# 2/2 [==============================] - 0s 67ms/step - loss: 0.9994 - val_loss: 0.9862
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3559
# Epoch 00020: val_loss did not improve from 0.98420
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9987 - val_loss: 0.9851
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3530
# Epoch 00021: val_loss improved from 0.98420 to 0.98365, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9972 - val_loss: 0.9837
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3497
# Epoch 00022: val_loss improved from 0.98365 to 0.98230, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9957 - val_loss: 0.9823
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3467
# Epoch 00023: val_loss improved from 0.98230 to 0.98115, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.9944 - val_loss: 0.9812
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3442
# Epoch 00024: val_loss improved from 0.98115 to 0.98020, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 0.9934 - val_loss: 0.9802
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3421
# Epoch 00025: val_loss improved from 0.98020 to 0.97945, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9924 - val_loss: 0.9795
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3403
# Epoch 00026: val_loss improved from 0.97945 to 0.97884, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9916 - val_loss: 0.9788
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3389
# Epoch 00027: val_loss improved from 0.97884 to 0.97833, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.9909 - val_loss: 0.9783
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3377
# Epoch 00028: val_loss improved from 0.97833 to 0.97791, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.9903 - val_loss: 0.9779
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3366
# Epoch 00029: val_loss improved from 0.97791 to 0.97756, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.9897 - val_loss: 0.9776
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3357
# Epoch 00030: val_loss improved from 0.97756 to 0.97725, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9892 - val_loss: 0.9772
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3348
# Epoch 00031: val_loss improved from 0.97725 to 0.97697, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9888 - val_loss: 0.9770
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3340
# Epoch 00032: val_loss improved from 0.97697 to 0.97673, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9883 - val_loss: 0.9767
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3333
# Epoch 00033: val_loss improved from 0.97673 to 0.97652, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.9879 - val_loss: 0.9765
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3326
# Epoch 00034: val_loss improved from 0.97652 to 0.97632, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9876 - val_loss: 0.9763
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3320
# Epoch 00035: val_loss improved from 0.97632 to 0.97612, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 111ms/step - loss: 0.9872 - val_loss: 0.9761
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3314
# Epoch 00036: val_loss improved from 0.97612 to 0.97593, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 0.9869 - val_loss: 0.9759
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3308
# Epoch 00037: val_loss improved from 0.97593 to 0.97576, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9867 - val_loss: 0.9758
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3303
# Epoch 00038: val_loss improved from 0.97576 to 0.97559, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9864 - val_loss: 0.9756
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3299
# Epoch 00039: val_loss improved from 0.97559 to 0.97544, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9862 - val_loss: 0.9754
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3294
# Epoch 00040: val_loss improved from 0.97544 to 0.97529, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 110ms/step - loss: 0.9859 - val_loss: 0.9753
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3289
# Epoch 00041: val_loss improved from 0.97529 to 0.97516, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9857 - val_loss: 0.9752
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3285
# Epoch 00042: val_loss improved from 0.97516 to 0.97503, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9855 - val_loss: 0.9750
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3281
# Epoch 00043: val_loss improved from 0.97503 to 0.97492, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.9853 - val_loss: 0.9749
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3277
# Epoch 00044: val_loss improved from 0.97492 to 0.97481, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9851 - val_loss: 0.9748
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3274
# Epoch 00045: val_loss improved from 0.97481 to 0.97471, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9850 - val_loss: 0.9747
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3270
# Epoch 00046: val_loss improved from 0.97471 to 0.97461, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 113ms/step - loss: 0.9848 - val_loss: 0.9746
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3267
# Epoch 00047: val_loss improved from 0.97461 to 0.97452, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9847 - val_loss: 0.9745
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3264
# Epoch 00048: val_loss improved from 0.97452 to 0.97444, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9845 - val_loss: 0.9744
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3261
# Epoch 00049: val_loss improved from 0.97444 to 0.97436, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9844 - val_loss: 0.9744
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3258
# Epoch 00050: val_loss improved from 0.97436 to 0.97428, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.9842 - val_loss: 0.9743
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3255
# Epoch 00051: val_loss improved from 0.97428 to 0.97421, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9841 - val_loss: 0.9742
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3253
# Epoch 00052: val_loss improved from 0.97421 to 0.97414, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9840 - val_loss: 0.9741
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3250
# Epoch 00053: val_loss improved from 0.97414 to 0.97406, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 113ms/step - loss: 0.9839 - val_loss: 0.9741
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3248
# Epoch 00054: val_loss improved from 0.97406 to 0.97399, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9838 - val_loss: 0.9740
# Epoch 55/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3245
# Epoch 00055: val_loss improved from 0.97399 to 0.97393, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.9837 - val_loss: 0.9739
# Epoch 56/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3243
# Epoch 00056: val_loss improved from 0.97393 to 0.97387, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9836 - val_loss: 0.9739
# Epoch 57/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3240
# Epoch 00057: val_loss improved from 0.97387 to 0.97381, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9835 - val_loss: 0.9738
# Epoch 58/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3238
# Epoch 00058: val_loss improved from 0.97381 to 0.97376, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.9834 - val_loss: 0.9738
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3236
# Epoch 00059: val_loss improved from 0.97376 to 0.97371, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.9833 - val_loss: 0.9737
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3234
# Epoch 00060: val_loss improved from 0.97371 to 0.97366, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 111ms/step - loss: 0.9832 - val_loss: 0.9737
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3233
# Epoch 00061: val_loss improved from 0.97366 to 0.97362, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9832 - val_loss: 0.9736
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3231
# Epoch 00062: val_loss improved from 0.97362 to 0.97357, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9831 - val_loss: 0.9736
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3229
# Epoch 00063: val_loss improved from 0.97357 to 0.97352, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9830 - val_loss: 0.9735
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3227
# Epoch 00064: val_loss improved from 0.97352 to 0.97347, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9830 - val_loss: 0.9735
# Epoch 65/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3225
# Epoch 00065: val_loss improved from 0.97347 to 0.97342, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9829 - val_loss: 0.9734
# Epoch 66/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3223
# Epoch 00066: val_loss improved from 0.97342 to 0.97338, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9828 - val_loss: 0.9734
# Epoch 67/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3222
# Epoch 00067: val_loss improved from 0.97338 to 0.97334, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.9827 - val_loss: 0.9733
# Epoch 68/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3220
# Epoch 00068: val_loss improved from 0.97334 to 0.97330, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 115ms/step - loss: 0.9827 - val_loss: 0.9733
# Epoch 69/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3219
# Epoch 00069: val_loss improved from 0.97330 to 0.97326, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9826 - val_loss: 0.9733
# Epoch 70/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3217
# Epoch 00070: val_loss improved from 0.97326 to 0.97322, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9826 - val_loss: 0.9732
# Epoch 71/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3216
# Epoch 00071: val_loss improved from 0.97322 to 0.97318, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9825 - val_loss: 0.9732
# Epoch 72/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3214
# Epoch 00072: val_loss improved from 0.97318 to 0.97315, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9825 - val_loss: 0.9731
# Epoch 73/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3213
# Epoch 00073: val_loss improved from 0.97315 to 0.97311, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9824 - val_loss: 0.9731
# Epoch 74/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3211
# Epoch 00074: val_loss improved from 0.97311 to 0.97307, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.9824 - val_loss: 0.9731
# Epoch 75/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3210
# Epoch 00075: val_loss improved from 0.97307 to 0.97304, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9823 - val_loss: 0.9730
# Epoch 76/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3209
# Epoch 00076: val_loss improved from 0.97304 to 0.97300, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9823 - val_loss: 0.9730
# Epoch 77/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3207
# Epoch 00077: val_loss improved from 0.97300 to 0.97297, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9822 - val_loss: 0.9730
# Epoch 78/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3206
# Epoch 00078: val_loss improved from 0.97297 to 0.97294, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9822 - val_loss: 0.9729
# Epoch 79/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3205
# Epoch 00079: val_loss improved from 0.97294 to 0.97291, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9821 - val_loss: 0.9729
# Epoch 80/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3204
# Epoch 00080: val_loss improved from 0.97291 to 0.97288, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.9821 - val_loss: 0.9729
# Epoch 81/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3203
# Epoch 00081: val_loss improved from 0.97288 to 0.97285, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.9820 - val_loss: 0.9728
# Epoch 82/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3202
# Epoch 00082: val_loss improved from 0.97285 to 0.97282, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9820 - val_loss: 0.9728
# Epoch 83/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3201
# Epoch 00083: val_loss improved from 0.97282 to 0.97280, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9820 - val_loss: 0.9728
# Epoch 84/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3200
# Epoch 00084: val_loss improved from 0.97280 to 0.97277, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.9819 - val_loss: 0.9728
# Epoch 85/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3199
# Epoch 00085: val_loss improved from 0.97277 to 0.97274, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.9819 - val_loss: 0.9727
# Epoch 86/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3198
# Epoch 00086: val_loss improved from 0.97274 to 0.97271, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9819 - val_loss: 0.9727
# Epoch 87/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3197
# Epoch 00087: val_loss improved from 0.97271 to 0.97268, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.9818 - val_loss: 0.9727
# Epoch 88/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3196
# Epoch 00088: val_loss improved from 0.97268 to 0.97265, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.9818 - val_loss: 0.9727
# Epoch 89/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3195
# Epoch 00089: val_loss improved from 0.97265 to 0.97263, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9818 - val_loss: 0.9726
# Epoch 90/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3194
# Epoch 00090: val_loss improved from 0.97263 to 0.97260, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9817 - val_loss: 0.9726
# Epoch 91/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3193
# Epoch 00091: val_loss improved from 0.97260 to 0.97257, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9817 - val_loss: 0.9726
# Epoch 92/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3192
# Epoch 00092: val_loss improved from 0.97257 to 0.97255, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.9817 - val_loss: 0.9725
# Epoch 93/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3191
# Epoch 00093: val_loss improved from 0.97255 to 0.97252, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.9816 - val_loss: 0.9725
# Epoch 94/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3191
# Epoch 00094: val_loss improved from 0.97252 to 0.97249, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.9816 - val_loss: 0.9725
# Epoch 95/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3190
# Epoch 00095: val_loss improved from 0.97249 to 0.97247, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9816 - val_loss: 0.9725
# Epoch 96/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3189
# Epoch 00096: val_loss improved from 0.97247 to 0.97244, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9816 - val_loss: 0.9724
# Epoch 97/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3188
# Epoch 00097: val_loss improved from 0.97244 to 0.97242, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9815 - val_loss: 0.9724
# Epoch 98/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3188
# Epoch 00098: val_loss improved from 0.97242 to 0.97240, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9815 - val_loss: 0.9724
# Epoch 99/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3187
# Epoch 00099: val_loss improved from 0.97240 to 0.97238, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.9815 - val_loss: 0.9724
# Epoch 100/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3186
# Epoch 00100: val_loss improved from 0.97238 to 0.97235, saving model to model\tmp_checkpoint_Covid.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9815 - val_loss: 0.9724

# %%
model.load_weights(filename)
pred = model.predict(test['Won'])

pred.shape
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FC25239EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (30, 1)

# %% [markdown]
# ### 9. 결과 표시

# %%
try:
    os.mkdir('./Result')
    print('폴더 생성 완료.')
    
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.')
# Out:
# 해당 폴더가 이미 존재합니다.

# %%
try:
    os.mkdir('./Result/CNN+LSTM')
    os.mkdir('./Result/CNN+LSTM/Graph')
    os.mkdir('./Result/CNN+LSTM/Data')
    print('폴더 생성 완료.')
    
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.')
# Out:
# 해당 폴더가 이미 존재합니다.

# %%
plt.title('Model Validation Loss', size='15')
plt.xlabel('Epoch')
plt.ylabel('Val_loss')
plt.grid(True)
plt.plot(history.history['val_loss'])
plt.savefig('./Result/CNN+LSTM/Graph/Model_Valdation_Loss.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 성능 측정 지표

# %%
from sklearn.metrics import r2_score as r2
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_squared_log_error as MSLE

print('r2 >> %.4f' %r2(test['Won'], pred)) # 1에 가까워야 좋음
print('MAE >> %.4f' %MAE(test['Won'], pred)) # 0에 가까워야 좋음
print('MSE >> %.4f' %MSE(test['Won'], pred)) # 0에 가까워야 좋음
print('RMSE >> %.4f' %np.sqrt(MSE(test['Won'], pred))) # 0에 가까워야 좋음
#print('RMSLE >> %.4f' %np.sqrt(MSLE(test['Won'], pred))) # 0에 가까워야 좋음
# Out:
# r2 >> -0.2060
# MAE >> 0.7370
# MSE >> 0.6927
# RMSE >> 0.8323

# %%
RMSE = np.sqrt(MSE(test['Won'], pred))
RMSE_pct = round(1-RMSE, 5)*100
print('RMSE 측정 정확도 ==>> %.3f %%' %RMSE_pct)
# Out:
# RMSE 측정 정확도 ==>> 16.770 %
